# %% [markdown]
# # Linear Regression and Error Curve Plot
# ### Carlos Marcelo Barrera Nolasco
# ### 101893

# %%
import pandas as pd
import numpy as np
from __future__ import division
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv("../../Recursos/regLin.csv")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[["X"]],df[[df.columns[1]]], train_size=0.75)

# %%
plt.scatter(X_train, Y_train)

# %% [markdown]
# ## Linear Regression

# %%
linReg = LinearRegression()
linReg.fit(X_train,Y_train)
print linReg.intercept_,linReg.coef_
np.mean((linReg.predict(X_test) - Y_test) **2)
# Out:
# [ 2.39385565] [[ 0.60868654]]
# y    17.946835
# dtype: float64

# %% [markdown]
# ## Prediction

# %%
Y_pred = linReg.predict(X_test)
plt.scatter(X_test, Y_test,  color='blue')
plt.plot(X_test, Y_pred, color='red', linewidth=3)

# %% [markdown]
# ## Calculating the error

# %%
def calcError(X,y,w,w0):
    return np.mean(((X.dot(w) + w0)[0]-y[y.columns[0]])**2)

# %%
print calcError(X_test, Y_test, linReg.coef_, linReg.intercept_)
print calcError(X_train, Y_train, linReg.coef_, linReg.intercept_)
# Out:
# 17.9468349454
# 16.630763754

# %%
yt_arr = []
w_arr = []
for x in range (190,350):
    w = x/100 
    w_arr.append(w)
    yt_arr.append(calcError(X_train, Y_train, linReg.coef_, w))

# %%
plt.plot(w_arr, yt_arr, color='red', linewidth=2)
plt.scatter(linReg.intercept_, calcError(X_train, Y_train, linReg.coef_, linReg.intercept_),  color='blue')

# %% [markdown]
# # Second File

# %%
df_2 = pd.read_csv("../../Recursos/regLin2.csv")

# %%
X_train_2, X_test_2, Y_train_2, Y_test_2 = train_test_split(df_2[["X"]],df_2[[df_2.columns[1]]], train_size=0.75)

# %%
plt.scatter(X_train_2, Y_train_2)

# %% [markdown]
# ## Linear Regression

# %%
linReg_2 = LinearRegression()
linReg_2.fit(X_train_2,Y_train_2)
print linReg_2.intercept_,linReg_2.coef_
# Out:
# [-944.97921241] [[ 60.92644101]]

# %% [markdown]
# ## Prediction

# %%
Y_pred_2 = linReg_2.predict(X_test_2)
plt.scatter(X_test_2, Y_test_2,  color='blue')
plt.plot(X_test_2, Y_pred_2, color='red', linewidth=3)

# %% [markdown]
# ## Calculating the error

# %%
print calcError(X_test_2, Y_test_2, linReg_2.coef_, linReg_2.intercept_)
print calcError(X_train_2, Y_train_2, linReg_2.coef_, linReg_2.intercept_)
# Out:
# 289631.975783
# 270644.882868

# %%
yt_arr_2 = []
w_arr_2 = []
min_w_2 = -1200
max_w_2 = -700
iterations = 200
for x in range (0,iterations):
    w = min_w_2+(max_w_2-min_w_2)*x/iterations 
    w_arr_2.append(w)
    yt_arr_2.append(calcError(X_train_2, Y_train_2, linReg_2.coef_, w))

# %%
plt.plot(w_arr_2, yt_arr_2, color='red', linewidth=2)
plt.scatter(linReg_2.intercept_, calcError(X_train_2, Y_train_2, linReg_2.coef_, linReg_2.intercept_),  color='blue')

# %% [markdown]
# # Third File

# %%
df_3 = pd.read_csv("../../Recursos/regLin3.csv")

# %%
X_train_3, X_test_3, Y_train_3, Y_test_3 = train_test_split(df_3[["X"]],df_3[[df_3.columns[1]]], train_size=0.75)

# %%
plt.scatter(X_train_3, Y_train_3)

# %% [markdown]
# ## Linear Regression

# %%
linReg_3 = LinearRegression()
linReg_3.fit(X_train_3,Y_train_3)
print linReg_3.intercept_,linReg_3.coef_
# Out:
# [ 0.02388152] [[-0.00120359]]

# %% [markdown]
# ## Prediction

# %%
Y_pred_3 = linReg_3.predict(X_test_3)
plt.scatter(X_test_3, Y_test_3,  color='blue')
plt.plot(X_test_3, Y_pred_3, color='red', linewidth=3)

# %% [markdown]
# ## Calculating the error

# %%
print calcError(X_test_3, Y_test_3, linReg_3.coef_, linReg_3.intercept_)
print calcError(X_train_3, Y_train_3, linReg_3.coef_, linReg_3.intercept_)
# Out:
# 0.511953562
# 0.482877737199

# %%
yt_arr_3 = []
w_arr_3 = []
min_w_3 = -5
max_w_3 = 5
iterations = 200
for x in range (0,iterations):
    w = min_w_3+(max_w_3-min_w_3)*x/iterations 
    w_arr_3.append(w)
    yt_arr_3.append(calcError(X_train_3, Y_train_3, linReg_3.coef_, w))

# %%
plt.plot(w_arr_3, yt_arr_3, color='red', linewidth=2)
plt.scatter(linReg_3.intercept_, calcError(X_train_3, Y_train_3, linReg_3.coef_, linReg_3.intercept_),  color='blue')
